# %% [markdown]
# # Spotify and Youtube Analysis
#
# ## Description
# An comparison of various metrics across Youtube and Spotify for various music tracks
#
# ## About the Dataset
# Link: https://www.kaggle.com/datasets/salvatorerastelli/spotify-and-youtube
#
# Dataset of songs of various artist in the world and for each song is present:
# Several statistics of the music version on spotify, including the number of streams.
# Number of views of the official music video of the song on youtube.
#
# It includes 26 variables for each of the songs collected from spotify. These variables are briefly described next:
#
# **Track**: name of the song, as visible on the Spotify platform.
# **Artist**: name of the artist.
# **Url_spotify**: the Url of the artist.
# **Album**: the album in wich the song is contained on Spotify.
# **Album_type**: indicates if the song is relesead on Spotify as a single or contained in an album.
# **Uri**: a spotify link used to find the song through the API.
# **Danceability**: describes how suitable a track is for dancing based on a combination of musical   elements including tempo, rhythm stability, beat strength, and overall regularity. A value of 0.0 is least danceable and 1.0 is most danceable.
# **Energy**: is a measure from 0.0 to 1.0 and represents a perceptual measure of intensity and activity. Typically, energetic tracks feel fast, loud, and noisy. For example, death metal has high energy, while a Bach prelude scores low on the scale. Perceptual features contributing to this attribute include dynamic range, perceived loudness, timbre, onset rate, and general entropy.
# **Key**: the key the track is in. Integers map to pitches using standard Pitch Class notation. E.g. 0 = C, 1 = C♯/D♭, 2 = D, and so on. If no key was detected, the value is -1.
# **Loudness**: the overall loudness of a track in decibels (dB). Loudness values are averaged across the entire track and are useful for comparing relative loudness of tracks. Loudness is the quality of a sound that is the primary psychological correlate of physical strength (amplitude). Values typically range between -60 and 0 db.
# **Speechiness**: detects the presence of spoken words in a track. The more exclusively speech-like the recording (e.g. talk show, audio book, poetry), the closer to 1.0 the attribute value. Values above 0.66 describe tracks that are probably made entirely of spoken words. Values between 0.33 and 0.66 describe tracks that may contain both music and speech, either in sections or layered, including such cases as rap music. Values below 0.33 most likely represent music and other non-speech-like tracks.
# **Acousticness**: a confidence measure from 0.0 to 1.0 of whether the track is acoustic. 1.0 represents high confidence the track is acoustic.
# **Instrumentalness**: predicts whether a track contains no vocals. "Ooh" and "aah" sounds are treated   as instrumental in this context. Rap or spoken word tracks are clearly "vocal". The closer the instrumentalness value is to 1.0, the greater likelihood the track contains no vocal content. Values above 0.5 are intended to represent instrumental tracks, but confidence is higher as the value approaches 1.0.
# **Liveness**: detects the presence of an audience in the recording. Higher liveness values represent an increased probability that the track was performed live. A value above 0.8 provides strong likelihood that the track is live.
# **Valence**: a measure from 0.0 to 1.0 describing the musical positiveness conveyed by a track. Tracks with high valence sound more positive (e.g. happy, cheerful, euphoric), while tracks with low valence sound more negative (e.g. sad, depressed, angry).
# **Tempo**: the overall estimated tempo of a track in beats per minute (BPM). In musical terminology,   tempo is the speed or pace of a given piece and derives directly from the average beat duration.
# **Duration_ms**: the duration of the track in milliseconds.
# **Stream**: number of streams of the song on Spotify.
# **Url_youtube**: url of the video linked to the song on Youtube, if it have any.
# **Title**: title of the videoclip on youtube.
# **Channel**: name of the channel that have published the video.
# **Views**: number of views.
# **Likes**: number of likes.
# **Comments**: number of comments.
# **Description**: description of the video on Youtube.
# **Licensed**: Indicates whether the video represents licensed content, which means that the content was uploaded to a channel linked to a YouTube content partner and then claimed by that partner.
# **official_video**: boolean value that indicates if the video found is the official video of the song.

# %%
import pandas as pd

path_to_csv = "./Spotify_Youtube.csv"

spyt_df = pd.read_csv(path_to_csv)

spyt_df.head()
# Out:
#    Unnamed: 0    Artist                                        Url_spotify  \
# 0           0  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 1           1  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 2           2  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 3           3  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 4           4  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
#
#                                            Track  \
# 0                                 Feel Good Inc.
# 1                                Rhinestone Eyes
# 2  New Gold (feat. Tame Impala and Bootie Brown)
# 3                             On Melancholy Hill
# 4                                 Clint Eastwood
#
#                                            Album Album_type  \
# 0                                     Demon Days      album
# 1                                  Plastic Beach      album
# 2  New Gold (feat. Tame Impala and Bootie Brown)     single
# 3                                  Plastic Beach      album
# 4                                       Gorillaz      album
#
#                                     Uri  Danceability  Energy   Key  ...  \
# 0  spotify:track:0d28khcov6AiegSCpG5TuT         0.818   0.705   6.0  ...
# 1  spotify:track:1foMv2HQwfQ2vntFf9HFeG         0.676   0.703   8.0  ...
# 2  spotify:track:64dLd6rVqDLtkXFYrEUHIU         0.695   0.923   1.0  ...
# 3  spotify:track:0q6LuUqGLUiCPP1cbdwFs3         0.689   0.739   2.0  ...
# 4  spotify:track:7yMiX7n9SBvadzox8T5jzT         0.663   0.694  10.0  ...
#
#                                    Url_youtube  \
# 0  https://www.youtube.com/watch?v=HyHNuVaZJ-k
# 1  https://www.youtube.com/watch?v=yYDmaexVHic
# 2  https://www.youtube.com/watch?v=qJa-VFwPpYA
# 3  https://www.youtube.com/watch?v=04mfKJWDSzI
# 4  https://www.youtube.com/watch?v=1V_xRb0x9aw
#
#                                                Title   Channel        Views  \
# 0         Gorillaz - Feel Good Inc. (Official Video)  Gorillaz  693555221.0
# 1  Gorillaz - Rhinestone Eyes [Storyboard Film] (...  Gorillaz   72011645.0
# 2  Gorillaz - New Gold ft. Tame Impala & Bootie B...  Gorillaz    8435055.0
# 3     Gorillaz - On Melancholy Hill (Official Video)  Gorillaz  211754952.0
# 4         Gorillaz - Clint Eastwood (Official Video)  Gorillaz  618480958.0
#
#        Likes  Comments                                        Description  \
# 0  6220896.0  169907.0  Official HD Video for Gorillaz' fantastic trac...
# 1  1079128.0   31003.0  The official video for Gorillaz - Rhinestone E...
# 2   282142.0    7399.0  Gorillaz - New Gold ft. Tame Impala & Bootie B...
# 3  1788577.0   55229.0  Follow Gorillaz online:\nhttp://gorillaz.com \...
# 4  6197318.0  155930.0  The official music video for Gorillaz - Clint ...
#
#    Licensed official_video        Stream
# 0      True           True  1.040235e+09
# 1      True           True  3.100837e+08
# 2      True           True  6.306347e+07
# 3      True           True  4.346636e+08
# 4      True           True  6.172597e+08
#
# [5 rows x 28 columns]

# %%
# Cleaning up unncessary columns
spyt_df.drop(columns=["Unnamed: 0", "Url_spotify", "Uri", "Url_youtube", "Description", "Title", "Channel"], inplace=True)

# %%
# Removing duplicates
duplicates = spyt_df.duplicated().sum()
print(duplicates)

## No duplicates found
# Out:
# 0

# %%
# Misssing values
missing = spyt_df.isnull().sum()
print(missing)
# Out:
# Artist                0
# Track                 0
# Album                 0
# Album_type            0
# Danceability          2
# Energy                2
# Key                   2
# Loudness              2
# Speechiness           2
# Acousticness          2
# Instrumentalness      2
# Liveness              2
# Valence               2
# Tempo                 2
# Duration_ms           2
# Views               470
# Likes               541
# Comments            569
# Licensed            470
# official_video      470
# Stream              576
# dtype: int64

# %% [markdown]
# #### Ran a check to see how much of the data missing constituted the overall data for the most relevant metrics
#
# Most affected columns:
# - Spotify-related fields: Stream ~2.78%
# - YouTube-related fields: Views ~2.27%

# %%
missing_stream = spyt_df["Stream"].isnull().sum()
percent_missing = (missing_stream / len(spyt_df)) * 100
print(f"Dropping Stream nulls would remove {missing_stream} rows ({percent_missing:.2f}%)")
# Out:
# Dropping Stream nulls would remove 576 rows (2.78%)

# %% [markdown]
# ###

# %%
missing_views = spyt_df["Views"].isnull().sum()
percent_missing = (missing_views / len(spyt_df)) * 100
print(f"Dropping Views nulls would remove {missing_views} rows ({percent_missing:.2f}%)")
# Out:
# Dropping Views nulls would remove 470 rows (2.27%)

# %%
spyt_df["missing_youtube_data"] = spyt_df["Views"].isnull()
spyt_df["missing_spotify_data"] = spyt_df["Stream"].isnull()
spyt_df['Comments'].fillna(0, inplace=True)
spyt_df['Likes'].fillna(0, inplace=True)
spyt_df.dropna(subset=['Danceability'], inplace=True)

# %%
spyt_df_clean = spyt_df[(spyt_df["missing_youtube_data"] == False) & (spyt_df["missing_spotify_data"] == False)]
missing = spyt_df_clean.isnull().sum()
print(missing)
# Out:
# Artist                  0
# Track                   0
# Album                   0
# Album_type              0
# Danceability            0
# Energy                  0
# Key                     0
# Loudness                0
# Speechiness             0
# Acousticness            0
# Instrumentalness        0
# Liveness                0
# Valence                 0
# Tempo                   0
# Duration_ms             0
# Views                   0
# Likes                   0
# Comments                0
# Licensed                0
# official_video          0
# Stream                  0
# missing_youtube_data    0
# missing_spotify_data    0
# dtype: int64

# %%
spyt_df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 19691 entries, 0 to 20717
# Data columns (total 23 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Artist                19691 non-null  object
#  1   Track                 19691 non-null  object
#  2   Album                 19691 non-null  object
#  3   Album_type            19691 non-null  object
#  4   Danceability          19691 non-null  float64
#  5   Energy                19691 non-null  float64
#  6   Key                   19691 non-null  float64
#  7   Loudness              19691 non-null  float64
#  8   Speechiness           19691 non-null  float64
#  9   Acousticness          19691 non-null  float64
#  10  Instrumentalness      19691 non-null  float64
#  11  Liveness              19691 non-null  float64
#  12  Valence               19691 non-null  float64
#  13  Tempo                 19691 non-null  float64
#  14  Duration_ms           19691 non-null  float64
#  15  Views                 19691 non-null  float64
#  16  Likes                 19691 non-null  float64
#  17  Comments              19691 non-null  float64
#  18  Licensed              19691 non-null  object
#  19  official_video        19691 non-null  object
#  20  Stream                19691 non-null  float64
#  21  missing_youtube_data  19691 non-null  bool
#  22  missing_spotify_data  19691 non-null  bool
# dtypes: bool(2), float64(15), object(6)
# memory usage: 3.3+ MB

# %%
# Convert columns to boolean
spyt_df_clean.loc[:, "Licensed"] = spyt_df_clean["Licensed"].astype(bool)
spyt_df_clean.loc[:, "official_video"] = spyt_df_clean["official_video"].astype(bool)

# Check data types
print(spyt_df_clean[["Licensed", "official_video"]].dtypes)
# Out:
# Licensed          object
# official_video    object
# dtype: object

# %%
spyt_df_clean.head(10)
# Out:
#      Artist                                              Track  \
# 0  Gorillaz                                     Feel Good Inc.
# 1  Gorillaz                                    Rhinestone Eyes
# 2  Gorillaz      New Gold (feat. Tame Impala and Bootie Brown)
# 3  Gorillaz                                 On Melancholy Hill
# 4  Gorillaz                                     Clint Eastwood
# 5  Gorillaz                                               DARE
# 6  Gorillaz  New Gold (feat. Tame Impala and Bootie Brown) ...
# 7  Gorillaz                 She's My Collar (feat. Kali Uchis)
# 8  Gorillaz                  Cracker Island (feat. Thundercat)
# 9  Gorillaz                                        Dirty Harry
#
#                                                Album Album_type  Danceability  \
# 0                                         Demon Days      album         0.818
# 1                                      Plastic Beach      album         0.676
# 2      New Gold (feat. Tame Impala and Bootie Brown)     single         0.695
# 3                                      Plastic Beach      album         0.689
# 4                                           Gorillaz      album         0.663
# 5                                         Demon Days      album         0.760
# 6  New Gold (feat. Tame Impala and Bootie Brown) ...     single         0.716
# 7                                    Humanz (Deluxe)      album         0.726
# 8                  Cracker Island (feat. Thundercat)     single         0.741
# 9                                         Demon Days      album         0.625
#
#    Energy   Key  Loudness  Speechiness  Acousticness  ...    Tempo  \
# 0   0.705   6.0    -6.679       0.1770      0.008360  ...  138.559
# 1   0.703   8.0    -5.815       0.0302      0.086900  ...   92.761
# 2   0.923   1.0    -3.930       0.0522      0.042500  ...  108.014
# 3   0.739   2.0    -5.810       0.0260      0.000015  ...  120.423
# 4   0.694  10.0    -8.627       0.1710      0.025300  ...  167.953
# 5   0.891  11.0    -5.852       0.0372      0.022900  ...  120.264
# 6   0.897   4.0    -7.185       0.0629      0.012000  ...  127.030
# 7   0.815  11.0    -5.886       0.0313      0.007990  ...  140.158
# 8   0.913   2.0    -3.340       0.0465      0.003430  ...  120.012
# 9   0.877  10.0    -7.176       0.1620      0.031500  ...  192.296
#
#    Duration_ms        Views      Likes  Comments  Licensed  official_video  \
# 0     222640.0  693555221.0  6220896.0  169907.0      True            True
# 1     200173.0   72011645.0  1079128.0   31003.0      True            True
# 2     215150.0    8435055.0   282142.0    7399.0      True            True
# 3     233867.0  211754952.0  1788577.0   55229.0      True            True
# 4     340920.0  618480958.0  6197318.0  155930.0      True            True
# 5     245000.0  259021161.0  1844658.0   72008.0      True            True
# 6     274142.0     451996.0    11686.0     241.0     False            True
# 7     209560.0    1010982.0    17675.0     260.0     False           False
# 8     213750.0   24459820.0   739527.0   20296.0      True            True
# 9     230426.0  154761056.0  1386920.0   39240.0      True            True
#
#          Stream missing_youtube_data missing_spotify_data
# 0  1.040235e+09                False                False
# 1  3.100837e+08                False                False
# 2  6.306347e+07                False                False
# 3  4.346636e+08                False                False
# 4  6.172597e+08                False                False
# 5  3.238503e+08                False                False
# 6  1.066615e+07                False                False
# 7  1.596059e+08                False                False
# 8  4.267190e+07                False                False
# 9  1.910747e+08                False                False
#
# [10 rows x 23 columns]

# %%
spyt_df_clean[spyt_df_clean["Loudness"] < 60]
# Out:
#                                  Artist                           Track  \
# 531                    Ludovico Einaudi                     Una Mattina
# 532                    Ludovico Einaudi                        The Tree
# 533                    Ludovico Einaudi                       Wind Song
# 534                    Ludovico Einaudi                        Luminous
# 536                    Ludovico Einaudi                   Natural Light
# ...                                 ...                             ...
# 20126                          Øneheart                    this feeling
# 20279  Solfeggio Healing Frequencies MT            528 Hz Manifest Love
# 20280  Solfeggio Healing Frequencies MT  528 Hz Manifest Your Greatness
# 20390                     Miracle Tones            528 Hz Manifest Love
# 20391                     Miracle Tones  528 Hz Manifest Your Greatness
#
#                          Album Album_type  Danceability   Energy   Key  \
# 531                Una Mattina      album         0.231  0.02970   2.0
# 532           Moments of Peace      album         0.316  0.00329   5.0
# 533                 Underwater      album         0.339  0.00572  11.0
# 534                 Underwater      album         0.307  0.00229   1.0
# 536                 Underwater      album         0.218  0.00352   1.0
# ...                        ...        ...           ...      ...   ...
# 20126             this feeling     single         0.172  0.01730  10.0
# 20279  528 Hz Meditation Music      album         0.168  0.06540   9.0
# 20280  528 Hz Meditation Music      album         0.162  0.06980   2.0
# 20390  528 Hz Meditation Music      album         0.168  0.06540   9.0
# 20391  528 Hz Meditation Music      album         0.162  0.06980   2.0
#
#        Loudness  Speechiness  Acousticness  ...    Tempo  Duration_ms  \
# 531     -31.544       0.0579         0.991  ...  131.413     203800.0
# 532     -38.901       0.0482         0.994  ...   90.804     199167.0
# 533     -32.309       0.0378         0.986  ...   72.700     198650.0
# 534     -34.977       0.0519         0.992  ...   67.775     283280.0
# 536     -39.627       0.0515         0.992  ...   68.610     335542.0
# ...         ...          ...           ...  ...      ...          ...
# 20126   -33.655       0.0358         0.916  ...  180.141      94333.0
# 20279   -30.119       0.0393         0.977  ...  138.061     106271.0
# 20280   -30.509       0.0684         0.954  ...  136.306     128625.0
# 20390   -30.119       0.0393         0.977  ...  138.061     106271.0
# 20391   -30.509       0.0684         0.954  ...  136.306     128625.0
#
#             Views     Likes  Comments  Licensed  official_video       Stream  \
# 531    18827869.0  185950.0    3358.0     False           False  177586576.0
# 532      241537.0    5145.0     235.0      True            True    3368451.0
# 533      703698.0   18068.0     389.0      True            True   16169290.0
# 534      602647.0   14581.0     417.0     False            True   30419886.0
# 536      653911.0   12247.0     409.0      True            True   31987794.0
# ...           ...       ...       ...       ...             ...          ...
# 20126    856049.0   32838.0     516.0      True            True   15596207.0
# 20279     21092.0     122.0       1.0      True            True   40723745.0
# 20280     18490.0     125.0       0.0      True            True   38778644.0
# 20390     21092.0     122.0       1.0      True            True   40673111.0
# 20391     18490.0     125.0       0.0      True            True   38728377.0
#
#       missing_youtube_data missing_spotify_data
# 531                  False                False
# 532                  False                False
# 533                  False                False
# 534                  False                False
# 536                  False                False
# ...                    ...                  ...
# 20126                False                False
# 20279                False                False
# 20280                False                False
# 20390                False                False
# 20391                False                False
#
# [143 rows x 23 columns]

# %%
## Checking the Spotify track variables for anomalies 

columns_to_check = [
    "Loudness", "Danceability", "Energy", "Speechiness", "Acousticness",
    "Instrumentalness", "Liveness", "Valence", "Tempo"
]

# Get the min and max for each column
print(spyt_df_clean[columns_to_check].agg(["min", "max"]).T)
# Out:
#                         min      max
# Loudness         -46.251000    0.920
# Danceability       0.000000    0.975
# Energy             0.000020    1.000
# Speechiness        0.000000    0.964
# Acousticness       0.000001    0.996
# Instrumentalness   0.000000    1.000
# Liveness           0.014500    1.000
# Valence            0.000000    0.993
# Tempo              0.000000  243.372

# %%
spyt_df_clean[spyt_df_clean["Loudness"] > 0].sort_values(by="Stream")
# Out:
#                        Artist  \
# 15187              Shilpi Raj
# 18354            Montell Fish
# 11826                 Cascada
# 9423                Sub Focus
# 10578  Sergio Vega "El Shaka"
# 12543          French Montana
#
#                                                    Track  \
# 15187                               Le Le Aayi Coca Cola
# 18354                                            Exscape
# 11826        Everytime We Touch - Fallen Superhero Remix
# 9423                                               Siren
# 10578                             Me Gusta Estar Contigo
# 12543  Welcome to the Party (with French Montana & Li...
#
#                                                    Album Album_type  \
# 15187                               Le Le Aayi Coca Cola     single
# 18354              Her Love Still Haunts Me Like a Ghost      album
# 11826        Everytime We Touch (Fallen Superhero Remix)     single
# 9423                                Solar System / Siren     single
# 10578                             Me Gusta Estar Contigo      album
# 12543  Welcome to the Party (with French Montana & Li...     single
#
#        Danceability  Energy  Key  Loudness  Speechiness  Acousticness  ...  \
# 15187         0.716   0.962  5.0     0.561       0.1010        0.3570  ...
# 18354         0.599   0.854  4.0     0.829       0.0373        0.6480  ...
# 11826         0.610   0.971  6.0     0.006       0.1690        0.0641  ...
# 9423          0.486   0.986  5.0     0.920       0.0620        0.1180  ...
# 10578         0.888   0.741  5.0     0.522       0.0573        0.4950  ...
# 12543         0.618   0.845  2.0     0.175       0.1320        0.1140  ...
#
#          Tempo  Duration_ms        Views      Likes  Comments  Licensed  \
# 15187  114.993     277569.0  327570837.0  2109990.0  107962.0      True
# 18354  139.995     142286.0     361642.0     8318.0     226.0     False
# 11826  150.089     218587.0    6967544.0    59878.0     636.0     False
# 9423   173.983     256000.0    1042170.0    16584.0     329.0      True
# 10578  105.789     138467.0    4976974.0     6740.0     191.0     False
# 12543  171.921     181720.0  207546580.0  2385757.0   69474.0     False
#
#        official_video       Stream missing_youtube_data missing_spotify_data
# 15187            True    3667356.0                False                False
# 18354            True    7762624.0                False                False
# 11826           False   12159973.0                False                False
# 9423             True   14126273.0                False                False
# 10578           False   25302700.0                False                False
# 12543            True  238992070.0                False                False
#
# [6 rows x 23 columns]

# %% [markdown]
# The expected range for Loudness should not be larger than 0 since it would indicate that it's louder than digital max in typical audio processing.
# Decided to sample some of the songs and there was no audible clipping.
#
# Some of these songs are extremely high in views and thus could impact data if they were removed, going with a median loudness.
# It only applies to 6 rows and will thus not impact a large segment of the data.

# %%
median_loudness = spyt_df_clean.loc[spyt_df_clean["Loudness"] <= 0, "Loudness"].median()

spyt_df_clean.loc[spyt_df_clean["Loudness"] > 0, "Loudness"] = median_loudness

print(spyt_df_clean["Loudness"].describe())
# Out:
# count    19691.000000
# mean        -7.643594
# std          4.618010
# min        -46.251000
# 25%         -8.785500
# 50%         -6.518000
# 75%         -4.932000
# max         -0.007000
# Name: Loudness, dtype: float64
